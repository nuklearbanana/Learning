# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import datasets
wine = datasets.load_wine()
dir(wine)
# Out:
# ['DESCR', 'data', 'feature_names', 'frame', 'target', 'target_names']

# %%
wine.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
df = pd.DataFrame(wine.data,columns=wine.feature_names)
df
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0      14.23        1.71  2.43               15.6      127.0           2.80
# 1      13.20        1.78  2.14               11.2      100.0           2.65
# 2      13.16        2.36  2.67               18.6      101.0           2.80
# 3      14.37        1.95  2.50               16.8      113.0           3.85
# 4      13.24        2.59  2.87               21.0      118.0           2.80
# ..       ...         ...   ...                ...        ...            ...
# 173    13.71        5.65  2.45               20.5       95.0           1.68
# 174    13.40        3.91  2.48               23.0      102.0           1.80
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 176    13.17        2.59  2.37               20.0      120.0           1.65
# 177    14.13        4.10  2.74               24.5       96.0           2.05
#
# ...

# %%
scaller = MinMaxScaler()
df_scalled = pd.DataFrame(scaller.fit_transform(df),columns=df.columns)
df_scalled.head()
# Out:
#     alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0  0.842105    0.191700  0.572193           0.257732   0.619565
# 1  0.571053    0.205534  0.417112           0.030928   0.326087
# 2  0.560526    0.320158  0.700535           0.412371   0.336957
# 3  0.878947    0.239130  0.609626           0.319588   0.467391
# 4  0.581579    0.365613  0.807487           0.536082   0.521739
#
#    total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0       0.627586    0.573840              0.283019         0.593060
# 1       0.575862    0.510549              0.245283         0.274448
# 2       0.627586    0.611814              0.320755         0.757098
# 3       0.989655    0.664557              0.207547         0.558360
# 4       0.627586    0.495781              0.490566         0.444795
#
#    color_intensity       hue  od280/od315_of_diluted_wines   proline
# 0         0.372014  0.455285                      0.970696  0.561341
# ...

# %%
from sklearn.naive_bayes import MultinomialNB,GaussianNB
from sklearn.pipeline import Pipeline
m_model = MultinomialNB()
g_model = GaussianNB()

# %%
mp = Pipeline([
    ('Scaler',MinMaxScaler()),
    ('Model',MultinomialNB())
])

gp = Pipeline([
    ('Scaler',MinMaxScaler()),
    ('Model',GaussianNB())
])

# %%
target = wine.target
X_train,X_test,y_train,y_test = train_test_split(df,target,test_size=0.3,random_state=100)

# %%
mp.fit(X_train,y_train)
gp.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('Scaler', MinMaxScaler()), ('Model', GaussianNB())])

# %%
mp.score(X_test,y_test)
# Out:
# 0.8888888888888888

# %%
gp.score(X_test,y_test)
# Out:
# 1.0

# %% [markdown]
# Gauussowskie jest lepsze

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(mp,df_scalled,target)
# Out:
# array([0.91666667, 0.94444444, 0.88888889, 0.97142857, 1.        ])

# %%
cross_val_score(gp,df_scalled,target)
# Out:
# array([0.94444444, 0.97222222, 0.97222222, 0.94285714, 1.        ])
